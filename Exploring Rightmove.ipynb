# %% [markdown]
# ## Introduction
#
# The purpose of this exploration is to scrape data from Rightmove property website and convert it into a format where we can analyse such as into a pandas DataFrame, or a .csv file.

# %%
rightmove_url = "https://www.rightmove.co.uk/property-for-sale/find.html?searchType=SALE&locationIdentifier=REGION%5E94022&insId=1&radius=0.0&minPrice=&maxPrice=&minBedrooms=&maxBedrooms=&displayPropertyType=&maxDaysSinceAdded=&_includeSSTC=on&sortByPriceDescending=&primaryDisplayPropertyType=&secondaryDisplayPropertyType=&oldDisplayPropertyType=&oldPrimaryDisplayPropertyType=&newHome=&auction=false"

# %%
# imports
from lxml import html, etree
import requests
import pandas as pd
import datetime as dt

# %%
response = requests.get(rightmove_url)

# %%
response.status_code
# Out:
# 200

# %%
response.content
# Out:
# b'<!DOCTYPE html>\n<html lang="en-GB" class="is-not-modern property-for-sale channel--buy ">\n<head>\n    <meta charset="utf-8">\n    <title>Properties For Sale in Liverpool City Centre - Flats &amp; Houses For Sale in Liverpool City Centre - Rightmove</title>\n    <meta http-equiv="X-UA-Compatible" content="IE=Edge"/>\n    <meta name="viewport" content="width=device-width, shrink-to-fit=no, initial-scale=1.0, user-scalable=no"/>\n    <meta name="format-detection" content="telephone=no"/>\n    <meta name="HandheldFriendly" content="True"/>\n    <meta name="description" content="Find Properties For Sale in Liverpool City Centre - Flats &amp; Houses For Sale in Liverpool City Centre - Rightmove. Search over 900,000 properties for sale from the top estate agents and developers in the UK - Rightmove."/>\n        <meta name="referrer" content="origin-when-cross-origin">\n    \n    <link rel="preconnect" href="https://media.rightmove.co.uk:443" crossorigin/>\n    <link rel="preconnect" href="//product.rightmove.co.uk" crossorigin/><link rel="shortcut icon" href="/pvw/images/favicons/rebranded/favicon.ico"><link rel="apple-touch-icon" sizes="72x72" href="/pvw/images/favicons/rebranded/apple-touch-icon-72x72.png">\n    <link rel="apple-touch-icon" sizes="114x114" href="/pvw/images/favicons/rebranded/apple-touch-icon-114x114.png">\n    <link rel="apple-touch-icon" sizes="120x120" href="/pvw/images/favicons/rebranded/apple-touch-icon-120x120.png">\n    <link rel="apple-touch-icon" sizes="144x144" href="/pvw/images/favicons/rebranded/apple-touch-icon-144x144.png">\n    <link rel="apple-touch-icon" sizes="152x152" href="/pvw/images/favicons/rebranded/apple-touch-icon-152x152.png"><meta name="msapplication-TileColor" content="#262637">\n    <meta name="msapplication-TileImage" content="/pvw/images/favicons/rebranded/mstile-144x144.png">\n\n            <meta name="msapplication-config" content="/pvw/images/favicons/rebranded/browserconfig.xml"><link rel="manifest" href="/pvw/images/favicons/rebranded/manifest.json">\n        <script>var RESOURCE_PREFIX = \'\';</script>\n        <meta name="apple-mobile-web-app-title" content="Rightmove">\n    <meta name="application-name" content="Rightmove">\n    <meta name="theme-color" content="#262637"><meta property="og:url" content="/"/>\n    <meta property="og:title" content="Rightmove.co.uk"/>\n    <meta property="og:type" content="website"/>\n    <meta property="og:image" content="/pvw/images/favicons/rebranded/logo-share-fb.png"/>\n    <meta property="og:locale" content="en_GB"/>\n    <meta property="og:site_name" content="Rightmove.co.uk"/>\n    <meta property="og:description" content="Search over a Million properties for sale and to rent from the top estate agents and developers in the UK"/>\n    <meta property="fb:admins" content="rightmove.plc"/>\n    <meta property="fb:app_id" content="485764298115191"/>\n    <meta property="twitter:account_id" content="2911111"/>\n    \n            <link rel="canonical" href="https://www.rightmove.co.uk/property-for-sale/Liverpool-City-Centre.html"/>\n    \n    <!--[if (lte IE 9)&(!IEMobile)]>\n    <script src="/pvw/javascript/oldie.0474dccaf4f58ea0200f.js"></script>\n    <![endif]-->\n    <!--[if (IE 8)&(!IEMobile)]>\n    <script>window.isIE8 = true;</script>\n    <![endif]-->\n    <!--[if (IE 9)&(!IEMobile)]>\n    <script>window.isIE9 = true;</script>\n    <![endif]--><style type="text/css">\n        svg {\n            display: none;\n        }\n    </style>\n        <style type=\'text/css\'>\n    @font-face {\n        font-family: \'effra-medium\';\n        src: url(\'/pvw/fonts/Effra_WLatn_Md.eot\'); /* IE9 Compat Modes */\n        src: /* IE6-IE8 */ url(\'/pvw/fonts/Effra_WLatn_Md.eot?#iefix\') format(\'embedded-opentype\'),\n            /* Super Modern Browsers */ url(\'/pvw/fonts/Effra_WLatn_Md.woff2\') format(\'woff2\'),\n            /* Pretty Modern Browsers */ url(\'/pvw/fonts/Effra_WLatn_Md.woff\') format(\'woff\');\n        font-style: normal;\n  ...

# %%
xp_prices = '//div[@class="propertyCard-priceValue"]/text()'
xp_weblinks = '//div[@class="propertyCard-details"]//a[@class="propertyCard-link"]/@href'
xp_titles = '//div[@class="propertyCard-details"]//a[@class="propertyCard-link"]\
//h2[@class="propertyCard-title"]/text()'
xp_addresses = '//address[@class="propertyCard-address"]/span/text()'

# %%
tree = html.fromstring(response.content)

# %%
price_pcm, titles, addresses, weblinks = [], [], [], []
for val in tree.xpath(xp_prices):
    price_pcm.append(val)
for val in tree.xpath(xp_titles):
    titles.append(val)
for val in tree.xpath(xp_addresses):
    addresses.append(val)
for val in tree.xpath(xp_weblinks):
    weblinks.append('http://www.rightmove.co.uk'+val)

# %%
len(price_pcm), len(titles), len(weblinks), len(addresses)
# Out:
# (25, 25, 25, 25)

# %%
tree.xpath(xp_addresses)
# Out:
# ['The Residence, Water Street, Liverpool, Merseyside, L2, WATER19',
#  'Moorfields, Liverpool, L2 2BS',
#  'The Strand, Liverpool, Merseyside, L2',
#  'Greenland Street, Liverpool, Merseyside, L1',
#  'Unity Building Rumford Place, Liverpool',
#  'Rumford Place, Liverpool, Merseyside, L3',
#  'Old Hall Street, Liverpool, L3',
#  'The Strand, Liverpool, Merseyside, L2',
#  'William Jessop Way, Liverpool, Merseyside, L3',
#  'Old Hall Street, Liverpool, L3',
#  'William Jessop Way, Liverpool',
#  'Mann Island, Liverpool, Merseyside, L3',
#  'The Strand, Liverpool, Merseyside, L2',
#  'Tower Building, 22 Water Street, Liverpool, L3',
#  'Mann Island, Liverpool, Merseyside, L3',
#  'Navigation Wharf, Liverpool, L3',
#  'Tower Building, Water Street, Liverpool, L3',
#  'Tower Building, Water Street, Liverpool, L3',
#  '19 Princes Parade, Liverpool, L3',
#  'Tower Building, Water Street, Liverpool, L3',
#  'The Colonnades Albert Dock, Liverpool, L3',
#  'Quebec Quay, Liverpool, L3',
#  'Tower Building, Water Street, Liverpool, L3',
#  'Wapping Quay, Liverpool, L3',
#  'The Reach, Liverpool']

# %%
data = [price_pcm, titles, weblinks, addresses]
temp_df = pd.DataFrame(data)
temp_df = temp_df.transpose()
temp_df.columns = ['price','type','url', 'address']

# %%
temp_df
# Out:
#                  price                                               type  \
# 0     £169,995          \n            2 bedroom apartment for sale    ...
# 1   £3,300,000                 \n            Studio flat for sale
# 2   £2,565,000          \n            2 bedroom apartment for sale    ...
# 3   £1,550,001          \n            3 bedroom penthouse for sale    ...
# 4     £900,000          \n            4 bedroom apartment for sale    ...
# 5     £899,950          \n            3 bedroom apartment for sale    ...
# 6     £795,000              \n            3 bedroom flat for sale
# 7     £750,000          \n            2 bedroom apartment for sale    ...
# 8     £748,500          \n            1 bedroom apartment for sale    ...
# 9     £700,000              \n            3 bedroom flat for sale
# 10    £619,000          \n            Block of apartments for sale    ...
# 11    £595,000              \n            3 bedroom flat for sale
# 12    £555,000          \n            2 bedroom apartment for sale    ...
# 13    £520,000          \n            3 bedroom penthouse for sale    ...
# 14    £399,950              \n            3 bedroom flat for sale
# 15    £365,000          \n            3 bedroom town house for sale   ...
# 16    £360,000          \n            2 bedroom apartment for sale    ...
# 17    £360,000          \n            2 bedroom apartment for sale    ...
# 18    £350,000          \n            2 bedroom apartment for sale    ...
# 19    £340,000          \n            2 bedroom apartment for sale    ...
# 20    £340,000              \n            2 bedroom flat for sale
# 21    £340,000          \n            2 bedroom penthouse for sale    ...
# 22    £336,000          \n            2 bedroom apartment for sale    ...
# 23    £330,000          \n            2 bedroom apartment for sale    ...
# 24    £310,000              \n            2 bedroom flat for sale
#
#                                                   url  \
# 0   http://www.rightmove.co.uk/property-for-sale/p...
# 1   http://www.rightmove.co.uk/property-for-sale/p...
# 2   http://www.rightmove.co.uk/property-for-sale/p...
# 3   http://www.rightmove.co.uk/property-for-sale/p...
# 4   http://www.rightmove.co.uk/property-for-sale/p...
# 5   http://www.rightmove.co.uk/property-for-sale/p...
# 6   http://www.rightmove.co.uk/property-for-sale/p...
# 7   http://www.rightmove.co.uk/property-for-sale/p...
# 8   http://www.rightmove.co.uk/property-for-sale/p...
# 9   http://www.rightmove.co.uk/property-for-sale/p...
# 10  http://www.rightmove.co.uk/property-for-sale/p...
# 11  http://www.rightmove.co.uk/property-for-sale/p...
# 12  http://www.rightmove.co.uk/property-for-sale/p...
# 13  http://www.rightmove.co.uk/property-for-sale/p...
# 14  http://www.rightmove.co.uk/property-for-sale/p...
# 15  http://www.rightmove.co.uk/property-for-sale/p...
# 16  http://www.rightmove.co.uk/property-for-sale/p...
# 17  http://www.rightmove.co.uk/property-for-sale/p...
# 18  http://www.rightmove.co.uk/property-for-sale/p...
# 19  http://www.rightmove.co.uk/property-for-sale/p...
# 20  http://www.rightmove.co.uk/property-for-sale/p...
# 21  http://www.rightmove.co.uk/property-for-sale/p...
# 22  http://www.rightmove.co.uk/property-for-sale/p...
# 23  http://www.rightmove.co.uk/property-for-sale/p...
# 24  http://www.rightmove.co.uk/property-for-sale/p...
#
#                                               address
# 0   The Residence, Water Street, Liverpool, Mersey...
# 1                       Moorfields, Liverpool, L2 2BS
# 2               The Strand, Liverpool, Merseyside, L2
# 3         Greenland Street, Liverpool, Merseyside, L1
# 4             Unity Building Rumford Place, Liverpool
# 5            Rumford Place, Liverpool, Merseyside, L3
# 6                      Old Hall Street, Liverpool, L3
# 7               The Strand, Liverpool, Merseyside, L2
# 8       William Jessop Way, Liverpool, Merseyside, L3
# 9                      Old Hall Street, Liverpool, L3
# 10                      William Jessop Way, Liverpool
# 11             Mann Island, Liverpool, Merseyside, L3
# 12              The Strand, Liverpool, Merseyside, L2
# 13     Tower Building, 22 Water Street, Liverpool, L3
# 14             Mann Island, Liverpool, Merseyside, L3
# 15                    Navigation Wharf, Liverpool, L3
# 16        Tower Building, Water Street, Liverpool, L3
# 17        Tower Building, Water Street, Liverpool, L3
# 18                   19 Princes Parade, Liverpool, L3
# 19        Tower Building, Water Street, Liverpool, L3
# 20          The Colonnades Albert Dock, Liverpool, L3
# 21                         Quebec Quay, Liverpool, L3
# 22        Tower Building, Water Street, Liverpool, L3
# 23                        Wapping Quay, Liverpool, L3
# 24                               The Reach, Liverpool

# %%
temp_df = temp_df[temp_df.url != 'http://www.rightmove.co.uk']

# %%
temp_df['number_bedrooms'] = temp_df.type.str.extract(r'\b([\d][\d]?)\b',expand=True)
temp_df.loc[temp_df['type'].str.contains('studio',case=False),'number_bedrooms']=0

# %%
temp_df
# Out:
#                  price                                               type  \
# 0     £169,995          \n            2 bedroom apartment for sale    ...
# 1   £3,300,000                 \n            Studio flat for sale
# 2   £2,565,000          \n            2 bedroom apartment for sale    ...
# 3   £1,550,001          \n            3 bedroom penthouse for sale    ...
# 4     £900,000          \n            4 bedroom apartment for sale    ...
# 5     £899,950          \n            3 bedroom apartment for sale    ...
# 6     £795,000              \n            3 bedroom flat for sale
# 7     £750,000          \n            2 bedroom apartment for sale    ...
# 8     £748,500          \n            1 bedroom apartment for sale    ...
# 9     £700,000              \n            3 bedroom flat for sale
# 10    £619,000          \n            Block of apartments for sale    ...
# 11    £595,000              \n            3 bedroom flat for sale
# 12    £555,000          \n            2 bedroom apartment for sale    ...
# 13    £520,000          \n            3 bedroom penthouse for sale    ...
# 14    £399,950              \n            3 bedroom flat for sale
# 15    £365,000          \n            3 bedroom town house for sale   ...
# 16    £360,000          \n            2 bedroom apartment for sale    ...
# 17    £360,000          \n            2 bedroom apartment for sale    ...
# 18    £350,000          \n            2 bedroom apartment for sale    ...
# 19    £340,000          \n            2 bedroom apartment for sale    ...
